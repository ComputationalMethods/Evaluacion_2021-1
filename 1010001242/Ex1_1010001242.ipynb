# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import numpy.linalg as la        #Importacion De Todas Las Librerias.
import math as m # real 
import cmath as cm # complex
from scipy import optimize
from scipy import misc

# %%
#Metodo FIXED POINT Desarrolado en el curso.
def FixedPoint_Animation( f, pini, Nmax, xmin, xmax ):
    g = lambda x: x-f(x)
    #Initial condition
    pi = [pini,]
    px = [pini,pini,]
    py = [0,]
    #Iterations
    for n in range(Nmax+3):
        pi.append( g(pi[n]) )
        px.append( g(pi[n]) )
        px.append( g(pi[n]) )
        py.append( g(pi[n]) )
        py.append( g(pi[n]) )
    
    py.append( g(pi[n+1]) )
    pi = np.array( pi )
    px = np.array( px )
    py = np.array( py )
    
    print ("Result:", pi[-1])
    
    #Array X-axis
    X = np.linspace(xmin,xmax,100)
    
    #Initializing Figure
    fig = plt.figure( figsize=(7,7) )
    ax = fig.add_subplot(111)
    #Graphic iterations
    fixedpoint, = ax.plot( [], [], color="red", linewidth = 3 )
    #Function g
    ax.plot( X, g(X), color="green", linewidth = 2 )
    #Identity funcion
    ax.plot( X, X, color="blue", linewidth = 2 )
    ax.grid(True)
    ax.set_xlim( (xmin, xmax) )
    ax.set_ylim( (xmin, xmax) )
    ax.set_xlabel( "X axis" )
    ax.set_ylabel( "Y axis" )
    ax.set_title( "Fixed-Point iteration" )
        
    def init():
        fixedpoint.set_data([], [])
        return fixedpoint,
    
    def animate(i):
        #Setting new data
        fixedpoint.set_data( px[:2*i], py[:2*i] )
        ax.set_title( "Fixed-Point. Iteration %d"%i )
        return fixedpoint,

# %%
R= np.random.randint(1,5)     #Escojemos El Numero Ramdom (INT) Para Escoger La Funcion.

print ('EL NUMERO ALEATORIO ELEGIDO ES= ', R)

P=np.random.rand(1)    #Se Elige El Numero P (FLOAT) Para igualar la funcion.

kkk=[0, '(SenX)/X= P','(SenX)/X= -P' ,'(CosX)/X= P', '(CosX)/X= -P']
print('LA FUNCION EQUIVALENTE ES:',kkk[R])
print ('EL VALOR DEL NUMERO P ES:', P)
print( 'LAS RAICES MAS CERCANAS AL INTERVALO [-10,10] SON:')

def F1(x):  
    P=np.random.rand(1)
    return ((np.sin(x))/x+P)
def F2(x): 
    P=np.random.rand(1)         #SE DEFINE CADA UNA DE LAS FUNCIONES.
    return ((np.sin(x))/x-P)
def F3(x): 
    P=np.random.rand(1)
    return ((np.cos(x))/x+P)
def F4(x): 
    P=np.random.rand(1)
    return ((np.sin(x))/x-P)

FUNCIONES=[0,F1,F2,F3,F4] #Almacenamos Cada Una De Las Opciones.
REALF=FUNCIONES[R]  #Funcion Obejtivo, lograda aplicando una mascara sobre la lista.


ROOTS=[] #Aplicando Fixed Point, Se Calculan Las Raices A Caulquiera De Las Opciones.
for i in range(10):
    f=FixedPoint_Animation(REALF,-1,i, -10,10)
    ROOTS=np.append(ROOTS,f)
print (ROOTS) #Se Muestran y Posteriormente se grafican.
# Out:
# EL NUMERO ALEATORIO ELEGIDO ES=  2
# LA FUNCION EQUIVALENTE ES: (SenX)/X= -P
# EL VALOR DEL NUMERO P ES: [0.83005667]
# LAS RAICES MAS CERCANAS AL INTERVALO [-10,10] SON:
# Result: [-1.299533]
# Result: [-2.15763628]
# Result: [-1.77425239]
# Result: [-1.83263549]
# Result: [-1.63141769]
# Result: [-1.40734753]
# Result: [-1.36382346]
# Result: [-1.88973257]
# Result: [-1.26779867]
# Result: [-1.64494592]
# [None None None None None None None None None None]
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# ...
