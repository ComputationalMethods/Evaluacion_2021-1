# %%
import pandas as pd
import numpy as np  #IMPORTACION DE LIBRERIAS.

df=pd.read_json("https://github.com/restrepo/anomaly/raw/main/solutions.json.gz") #Importamos Toda la base de datos.
df
# Out:
#                          l                    k  \
# 0       [-1, 0, -1, 0, -1]   [-1, 0, -1, 1, -1]
# 1                  [-1, 1]          [-1, 0, -1]
# 2        [1, -1, 0, 1, -1]   [-2, 0, -1, -2, 0]
# 3       [-1, 1, -1, 1, -1]   [-2, -1, 0, -1, 0]
# 4         [1, 0, 1, 0, -1]  [-2, -1, -2, -1, 0]
# ...                    ...                  ...
# 390069       [-3, -15, -6]           [-3, 8, 9]
# 390070      [-10, -5, -15]       [-10, -12, 12]
# 390071        [15, -1, 15]      [-14, -13, -14]
# 390072       [-15, -9, -1]      [-13, -14, -12]
# 390073         [10, 15, 5]        [-11, -14, 7]
#
#                                           solution   gcd   n
# 0           [1, 4, 4, 4, -5, -5, -5, -5, -5, 6, 6]     1  11
# 1                         [1, 2, 2, -3, -3, -3, 4]     1   7
# 2       [1, 1, -2, -2, -3, -3, 5, 5, 5, 5, -6, -6]     2  12
# 3         [1, 1, 1, 1, 2, 2, 2, -3, -4, -4, -6, 7]     1  12
# 4           [1, 1, 1, -2, -2, -5, -5, 6, 6, 7, -8]     1  11
# ...

# %%
#VALOR MAXIMO
def MAX(x):
    m=sorted( np.abs(x) ) #Definimos Funcion Para El Valor Absoluto.
    return m[-1]
#COLUMNAS
df["N_Max"]=df["solution"].apply(MAX)          #Columna Con El Valor Maximo En Valor Absoluto.
df["Sum_1"]=df["solution"].apply(sum)          #Columna con la suma de Solution.
df["Sum_3"]=(df["solution"].apply(sum))**3     #Columna Con La Suma, Al Cubo, del label Solution.

#GRaficacion nuevo Dataframe.
df
# Out:
#                          l                    k  \
# 0       [-1, 0, -1, 0, -1]   [-1, 0, -1, 1, -1]
# 1                  [-1, 1]          [-1, 0, -1]
# 2        [1, -1, 0, 1, -1]   [-2, 0, -1, -2, 0]
# 3       [-1, 1, -1, 1, -1]   [-2, -1, 0, -1, 0]
# 4         [1, 0, 1, 0, -1]  [-2, -1, -2, -1, 0]
# ...                    ...                  ...
# 390069       [-3, -15, -6]           [-3, 8, 9]
# 390070      [-10, -5, -15]       [-10, -12, 12]
# 390071        [15, -1, 15]      [-14, -13, -14]
# 390072       [-15, -9, -1]      [-13, -14, -12]
# 390073         [10, 15, 5]        [-11, -14, 7]
#
#                                           solution   gcd   n  N_Max  Sum_1  \
# 0           [1, 4, 4, 4, -5, -5, -5, -5, -5, 6, 6]     1  11      6      0
# 1                         [1, 2, 2, -3, -3, -3, 4]     1   7      4      0
# 2       [1, 1, -2, -2, -3, -3, 5, 5, 5, 5, -6, -6]     2  12      6      0
# 3         [1, 1, 1, 1, 2, 2, 2, -3, -4, -4, -6, 7]     1  12      7      0
# ...
